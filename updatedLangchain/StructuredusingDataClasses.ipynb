# %%
from dataclasses import dataclass
from langchain.agents import create_agent


@dataclass
class Movie:
    name: str
    year: int
    director: str
    rating: float

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama-3.1-8b-instant",
    model_provider="groq",
)

# %%
structured_output = model.with_structured_output(Movie)

# %%
result = structured_output.invoke(
    "Provide KGF Movie Details. "
    
)

print(result)
print(type(result))
# Out:
# {'director': 'Prashanth Neel', 'name': 'K.G.F.', 'rating': 8.1, 'year': 2018}
# <class 'dict'>

# %%
from dataclasses import dataclass
from langchain.agents import create_agent


@dataclass
class Movie:
    name: str
    year: int
    director: str
    rating: float

### Create an Agent and Invoke the Movie Class
agent = create_agent(
    model = model,
    tools = [],
    response_format = Movie
)

result = agent.invoke({
    "messages":[{
        "role":"user",
        "content": (
            "Provide one famous movie with name, year, director, and rating. "
            "Do not search the web."
        )
    }]
})
result
# Out:
# {'messages': [HumanMessage(content='Provide one famous movie with name, year, director, and rating. Do not search the web.', additional_kwargs={}, response_metadata={}, id='144d184c-ee16-4d7e-bf89-8966458a1fde'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'frk3b61kn', 'function': {'arguments': '{"director":"Frank Darabont","name":"The Shawshank Redemption","rating":9.2,"year":1994}', 'name': 'Movie'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 290, 'total_tokens': 328, 'completion_time': 0.040475872, 'completion_tokens_details': None, 'prompt_time': 0.01916466, 'prompt_tokens_details': None, 'queue_time': 0.05551906, 'total_time': 0.059640532}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_1151d4f23c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b7885-c189-7570-9471-499dfa5092a3-0', tool_calls=[{'name': 'Movie', 'args': {'director': 'Frank Darabont', 'name': 'The Shawshank Redemption', 'rating': 9.2, 'year': 1994}, 'id': 'frk3b61kn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 290, 'output_tokens': 38, 'total_tokens': 328}),
#   ToolMessage(content="Returning structured response: Movie(name='The Shawshank Redemption', year=1994, director='Frank Darabont', rating=9.2)", name='Movie', id='3ec07b04-bfb3-448e-8ca5-4b993383e229', tool_call_id='frk3b61kn')],
#  'structured_response': Movie(name='The Shawshank Redemption', year=1994, director='Frank Darabont', rating=9.2)}
